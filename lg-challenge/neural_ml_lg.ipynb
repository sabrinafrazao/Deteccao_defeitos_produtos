# %%
import pandas as pd
import os

current_dir = os.getcwd()
path_file = os.path.join(current_dir, "product_quality_dataset.csv")
df = pd.read_csv(path_file, header=0)

df.head()
# Out:
#    Power Consumption (kW)  Cooling Capacity (BTU)  Noise Level (dB)   EER  \
# 0                    2.87                   24000             47.39  3.55
# 1                    5.75                   18000             44.66  3.28
# 2                    4.66                   30000             46.25  3.82
# 3                    3.99                    9000             40.67  2.72
# 4                    1.78                   30000             57.23  3.77
#
#    Temperature Range (°C)  Airflow (m³/min)  Warranty (Years)  \
# 0                      20              9.20                 3
# 1                      30             12.01                 5
# 2                      30             29.23                 6
# 3                      18             17.42                 3
# 4                      30             21.90                 3
#
#    Build Quality Rating  Maintenance Cost ($)  Type  Efficiency Score
# 0                    10                   188     0                96
# 1                     6                   297     1                77
# 2                     5                   381     1                83
# 3                     9                   299     1                75
# 4                     3                   198     0                84

# %%
df.isnull().any()
# Out:
# Power Consumption (kW)    False
# Cooling Capacity (BTU)    False
# Noise Level (dB)          False
# EER                       False
# Temperature Range (°C)    False
# Airflow (m³/min)          False
# Warranty (Years)          False
# Build Quality Rating      False
# Maintenance Cost ($)      False
# Type                      False
# Efficiency Score          False
# dtype: bool

# %%
df.describe()
# Out:
#        Power Consumption (kW)  Cooling Capacity (BTU)  Noise Level (dB)  \
# count             1000.000000             1000.000000       1000.000000
# mean                 3.451220            18807.000000         47.602570
# std                  1.460649             7808.887868          7.315986
# min                  1.020000             9000.000000         35.000000
# 25%                  2.182500            12000.000000         41.040000
# 50%                  3.485000            18000.000000         48.040000
# 75%                  4.722500            24000.000000         53.850000
# max                  6.000000            30000.000000         59.990000
#
#                EER  Temperature Range (°C)  Airflow (m³/min)  \
# count  1000.000000             1000.000000       1000.000000
# mean      3.528640               21.878000         18.879740
# std       0.567161                5.313695          6.301974
# min       2.500000               15.000000          8.040000
# 25%       3.060000               18.000000         13.507500
# 50%       3.540000               20.000000         18.830000
# 75%       4.020000               25.000000         24.420000
# max       4.500000               30.000000         29.980000
#
#        Warranty (Years)  Build Quality Rating  Maintenance Cost ($)  \
# count       1000.000000           1000.000000           1000.000000
# mean           3.959000              5.551000            293.900000
# std            1.411138              2.963137            114.652864
# min            2.000000              1.000000            100.000000
# 25%            3.000000              3.000000            188.000000
# 50%            4.000000              6.000000            294.000000
# 75%            5.000000              8.000000            392.000000
# max            6.000000             10.000000            499.000000
#
#               Type  Efficiency Score
# count  1000.000000       1000.000000
# mean      0.491000         80.218000
# std       0.500169         12.886448
# min       0.000000         48.000000
# 25%       0.000000         70.000000
# 50%       0.000000         81.000000
# 75%       1.000000         91.000000
# max       1.000000        100.000000

# %%
# print('Numbers of rows with 0 values for each variable')
# for col in df.columns:
#     missing_rows = df.loc[df[col] == 0].shape[0]
#     print(col + ': ' + str(missing_rows))

# %%
# # Padronização dos dados
# import numpy as np

# df['Glucose'] = df['Glucose'].replace(0, np.nan)
# df['BloodPressure'] = df['BloodPressure'].replace(0, np.nan)
# df['SkinThickness'] = df['SkinThickness'].replace(0, np.nan)
# df['Insulin'] = df['Insulin'].replace(0, np.nan)
# df['BMI'] = df['BMI'].replace(0, np.nan)

# print('Numbers of rows with 0 values for each variable')
# for col in df.columns:
#     missing_rows = df.loc[df[col] == 0].shape[0]
#     print(col + ': ' + str(missing_rows))

# %%
# df['Glucose'] = df['Glucose'].fillna(df['Glucose'].mean())
# df['BloodPressure'] = df['BloodPressure'].fillna(df['BloodPressure'].mean())
# df['SkinThickness'] = df['SkinThickness'].fillna(df['SkinThickness'].mean())
# df['Insulin'] = df['Insulin'].fillna(df['Insulin'].mean())
# df['BMI'] = df['BMI'].fillna(df['BMI'].mean())

# # print('Numbers of rows with 0 values for each variable')
# # for col in df.columns:
# #     missing_rows = df.loc[df[col] == 0].shape[0]
# #     print(col + ': ' + str(missing_rows))

# %%
from sklearn import preprocessing

df_scaled = preprocessing.scale(df)
df_scaled = pd.DataFrame(df_scaled, columns=df.columns)

# print('Numbers of rows with 0 values for each variable')
# for col in df_scaled.columns:
#     missing_rows = df_scaled.loc[df_scaled[col] == 0].shape[0]
#     print(col + ': ' + str(missing_rows))

# %%
df_scaled['Type'] = df['Type']
df = df_scaled
df.describe().loc[['mean', 'std', 'max', 'min'],].round(2).abs()
# Out:
#       Power Consumption (kW)  Cooling Capacity (BTU)  Noise Level (dB)   EER  \
# mean                    0.00                    0.00              0.00  0.00
# std                     1.00                    1.00              1.00  1.00
# max                     1.75                    1.43              1.69  1.71
# min                     1.67                    1.26              1.72  1.81
#
#       Temperature Range (°C)  Airflow (m³/min)  Warranty (Years)  \
# mean                    0.00              0.00              0.00
# std                     1.00              1.00              1.00
# max                     1.53              1.76              1.45
# min                     1.30              1.72              1.39
#
#       Build Quality Rating  Maintenance Cost ($)  Type  Efficiency Score
# mean                  0.00                  0.00  0.49              0.00
# std                   1.00                  1.00  0.50              1.00
# max                   1.50                  1.79  1.00              1.54
# min                   1.54                  1.69  0.00              2.50

# %%
# print('Numbers of rows with 0 values for each variable')
# for col in df.columns:
#     missing_rows = df.loc[df[col] == 0].shape[0]
#     print(col + ': ' + str(missing_rows))

# %%
X = df.loc[:, df.columns != 'Type']
y = df.loc[:, 'Type']

# %%
from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=1)

# %%
print("X_train shape:", X_train.shape)
print("X_val shape:", X_val.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_val shape:", y_val.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (600, 10)
# X_val shape: (200, 10)
# X_test shape: (200, 10)
# y_train shape: (600,)
# y_val shape: (200,)
# y_test shape: (200,)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input

model = Sequential()
model.add(Input(shape=(10,)))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
from sklearn import preprocessing

model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.5283 - loss: 0.8365 - val_accuracy: 0.4750 - val_loss: 0.7874
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5357 - loss: 0.7303 - val_accuracy: 0.4750 - val_loss: 0.7312
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5289 - loss: 0.7024 - val_accuracy: 0.5050 - val_loss: 0.7103
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5017 - loss: 0.7088 - val_accuracy: 0.5250 - val_loss: 0.6997
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5896 - loss: 0.6758 - val_accuracy: 0.5500 - val_loss: 0.6958
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5338 - loss: 0.6921 - val_accuracy: 0.5650 - val_loss: 0.6922
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5735 - loss: 0.6767 - val_accuracy: 0.5650 - val_loss: 0.6911
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5822 - loss: 0.6807 - val_accuracy: 0.5650 - val_loss: 0.6879
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5825 - loss: 0.6793 - val_accuracy: 0.5650 - val_loss: 0.6869
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6140 - loss: 0.6690 - val_accuracy: 0.5500 - val_loss: 0.6856
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5693 - loss: 0.6776 - val_accuracy: 0.5500 - val_loss: 0.6847
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5751 - loss: 0.6792 - val_accuracy: 0.5500 - val_loss: 0.6842
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6096 - loss: 0.6665 - val_accuracy: 0.5550 - val_loss: 0.6843
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6017 - loss: 0.6706 - val_accuracy: 0.5650 - val_loss: 0.6836
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6032 - loss: 0.6649 - val_accuracy: 0.5700 - val_loss: 0.6824
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6195 - loss: 0.6557 - val_accuracy: 0.5750 - val_loss: 0.6841
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5947 - loss: 0.6647 - val_accuracy: 0.5900 - val_loss: 0.6823
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6361 - loss: 0.6525 - val_accuracy: 0.5950 - val_loss: 0.6826
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6225 - loss: 0.6447 - val_accuracy: 0.6050 - val_loss: 0.6842
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6204 - loss: 0.6529 - val_accuracy: 0.6150 - val_loss: 0.6821
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6320 - loss: 0.6553 - val_accuracy: 0.5900 - val_loss: 0.6834
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6377 - loss: 0.6516 - val_accuracy: 0.6000 - val_loss: 0.6831
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6218 - loss: 0.6496 - val_accuracy: 0.5900 - val_loss: 0.6846
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6199 - loss: 0.6463 - val_accuracy: 0.5950 - val_loss: 0.6850
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6378 - loss: 0.6409 - val_accuracy: 0.6000 - val_loss: 0.6850
# Epoch 26/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6668 - loss: 0.6318 - val_accuracy: 0.6050 - val_loss: 0.6852
# Epoch 27/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6488 - loss: 0.6367 - val_accuracy: 0.6050 - val_loss: 0.6858
# Epoch 28/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6314 - loss: 0.6372 - val_accuracy: 0.6050 - val_loss: 0.6865
# Epoch 29/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6298 - loss: 0.6341 - val_accuracy: 0.6000 - val_loss: 0.6894
# Epoch 30/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6356 - loss: 0.6376 - val_accuracy: 0.6100 - val_loss: 0.6867
# Epoch 31/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6401 - loss: 0.6289 - val_accuracy: 0.5950 - val_loss: 0.6902
# Epoch 32/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6506 - loss: 0.6315 - val_accuracy: 0.6000 - val_loss: 0.6903
# Epoch 33/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6394 - loss: 0.6247 - val_accuracy: 0.6050 - val_loss: 0.6906
# Epoch 34/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6398 - loss: 0.6348 - val_accuracy: 0.5850 - val_loss: 0.6921
# Epoch 35/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6479 - loss: 0.6098 - val_accuracy: 0.5800 - val_loss: 0.6935
# Epoch 36/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6390 - loss: 0.6226 - val_accuracy: 0.5900 - val_loss: 0.6946
# Epoch 37/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6449 - loss: 0.6174 - val_accuracy: 0.5750 - val_loss: 0.6963
# Epoch 38/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6621 - loss: 0.6111 - val_accuracy: 0.5800 - val_loss: 0.6958
# Epoch 39/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6459 - loss: 0.6200 - val_accuracy: 0.5650 - val_loss: 0.6978
# Epoch 40/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6686 - loss: 0.6096 - val_accuracy: 0.5850 - val_loss: 0.6980
# Epoch 41/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6384 - loss: 0.6173 - val_accuracy: 0.5750 - val_loss: 0.7002
# Epoch 42/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6943 - loss: 0.6063 - val_accuracy: 0.5850 - val_loss: 0.7016
# Epoch 43/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6896 - loss: 0.5867 - val_accuracy: 0.5850 - val_loss: 0.7028
# Epoch 44/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6932 - loss: 0.5882 - val_accuracy: 0.5800 - val_loss: 0.7069
# Epoch 45/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7000 - loss: 0.5875 - val_accuracy: 0.5900 - val_loss: 0.7062
# Epoch 46/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7197 - loss: 0.5780 - val_accuracy: 0.5900 - val_loss: 0.7078
# Epoch 47/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7072 - loss: 0.5794 - val_accuracy: 0.5750 - val_loss: 0.7075
# Epoch 48/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7028 - loss: 0.5837 - val_accuracy: 0.5800 - val_loss: 0.7084
# Epoch 49/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6841 - loss: 0.5929 - val_accuracy: 0.5800 - val_loss: 0.7113
# Epoch 50/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6941 - loss: 0.5823 - val_accuracy: 0.5750 - val_loss: 0.7100
# Epoch 51/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6836 - loss: 0.5841 - val_accuracy: 0.5750 - val_loss: 0.7111
# Epoch 52/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6970 - loss: 0.5738 - val_accuracy: 0.5700 - val_loss: 0.7145
# Epoch 53/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7060 - loss: 0.5692 - val_accuracy: 0.5750 - val_loss: 0.7135
# Epoch 54/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7024 - loss: 0.5775 - val_accuracy: 0.5650 - val_loss: 0.7159
# Epoch 55/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6939 - loss: 0.5723 - val_accuracy: 0.5750 - val_loss: 0.7189
# Epoch 56/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7031 - loss: 0.5732 - val_accuracy: 0.5750 - val_loss: 0.7156
# Epoch 57/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7088 - loss: 0.5701 - val_accuracy: 0.5750 - val_loss: 0.7166
# Epoch 58/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7055 - loss: 0.5622 - val_accuracy: 0.5650 - val_loss: 0.7263
# Epoch 59/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7360 - loss: 0.5489 - val_accuracy: 0.5850 - val_loss: 0.7182
# Epoch 60/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6955 - loss: 0.5590 - val_accuracy: 0.5850 - val_loss: 0.7211
# Epoch 61/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7172 - loss: 0.5439 - val_accuracy: 0.5700 - val_loss: 0.7265
# Epoch 62/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7165 - loss: 0.5596 - val_accuracy: 0.5700 - val_loss: 0.7256
# Epoch 63/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7199 - loss: 0.5565 - val_accuracy: 0.5850 - val_loss: 0.7265
# Epoch 64/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7244 - loss: 0.5492 - val_accuracy: 0.5650 - val_loss: 0.7313
# Epoch 65/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7200 - loss: 0.5527 - val_accuracy: 0.5600 - val_loss: 0.7324
# Epoch 66/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7351 - loss: 0.5471 - val_accuracy: 0.5750 - val_loss: 0.7307
# Epoch 67/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7739 - loss: 0.5145 - val_accuracy: 0.5700 - val_loss: 0.7367
# Epoch 68/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7495 - loss: 0.5351 - val_accuracy: 0.5700 - val_loss: 0.7357
# Epoch 69/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7476 - loss: 0.5153 - val_accuracy: 0.5650 - val_loss: 0.7390
# Epoch 70/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7420 - loss: 0.5468 - val_accuracy: 0.5800 - val_loss: 0.7382
# Epoch 71/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7596 - loss: 0.5013 - val_accuracy: 0.5600 - val_loss: 0.7468
# Epoch 72/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7315 - loss: 0.5348 - val_accuracy: 0.5600 - val_loss: 0.7430
# Epoch 73/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7518 - loss: 0.5269 - val_accuracy: 0.5600 - val_loss: 0.7504
# Epoch 74/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7760 - loss: 0.5009 - val_accuracy: 0.5600 - val_loss: 0.7463
# Epoch 75/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7616 - loss: 0.5161 - val_accuracy: 0.5600 - val_loss: 0.7505
# Epoch 76/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7604 - loss: 0.5125 - val_accuracy: 0.5450 - val_loss: 0.7515
# Epoch 77/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7220 - loss: 0.5326 - val_accuracy: 0.5600 - val_loss: 0.7539
# Epoch 78/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7515 - loss: 0.5125 - val_accuracy: 0.5650 - val_loss: 0.7550
# Epoch 79/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7648 - loss: 0.5010 - val_accuracy: 0.5500 - val_loss: 0.7584
# Epoch 80/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7700 - loss: 0.5039 - val_accuracy: 0.5500 - val_loss: 0.7640
# Epoch 81/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7584 - loss: 0.5125 - val_accuracy: 0.5550 - val_loss: 0.7613
# Epoch 82/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7761 - loss: 0.5038 - val_accuracy: 0.5500 - val_loss: 0.7643
# Epoch 83/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7745 - loss: 0.5016 - val_accuracy: 0.5550 - val_loss: 0.7726
# Epoch 84/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7820 - loss: 0.4919 - val_accuracy: 0.5550 - val_loss: 0.7698
# Epoch 85/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7868 - loss: 0.4809 - val_accuracy: 0.5550 - val_loss: 0.7685
# Epoch 86/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7887 - loss: 0.4923 - val_accuracy: 0.5600 - val_loss: 0.7692
# Epoch 87/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7691 - loss: 0.5082 - val_accuracy: 0.5500 - val_loss: 0.7770
# Epoch 88/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7862 - loss: 0.4780 - val_accuracy: 0.5400 - val_loss: 0.7754
# Epoch 89/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7346 - loss: 0.4999 - val_accuracy: 0.5400 - val_loss: 0.7813
# Epoch 90/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7768 - loss: 0.4785 - val_accuracy: 0.5550 - val_loss: 0.7820
# Epoch 91/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7765 - loss: 0.4789 - val_accuracy: 0.5450 - val_loss: 0.7814
# Epoch 92/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7832 - loss: 0.4668 - val_accuracy: 0.5400 - val_loss: 0.7906
# Epoch 93/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7451 - loss: 0.4968 - val_accuracy: 0.5450 - val_loss: 0.7860
# Epoch 94/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7919 - loss: 0.4641 - val_accuracy: 0.5550 - val_loss: 0.7918
# Epoch 95/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7997 - loss: 0.4571 - val_accuracy: 0.5450 - val_loss: 0.7966
# Epoch 96/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7887 - loss: 0.4772 - val_accuracy: 0.5450 - val_loss: 0.7923
# Epoch 97/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7940 - loss: 0.4649 - val_accuracy: 0.5500 - val_loss: 0.7963
# Epoch 98/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7932 - loss: 0.4797 - val_accuracy: 0.5450 - val_loss: 0.8009
# Epoch 99/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7897 - loss: 0.4660 - val_accuracy: 0.5400 - val_loss: 0.7947
# Epoch 100/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8026 - loss: 0.4577 - val_accuracy: 0.5400 - val_loss: 0.8051

# %%
scores = model.evaluate(X_train, y_train)
print('Training Accuracy: %.2f%%\n' % (scores[1]*100))

scores = model.evaluate(X_val, y_val)
print('Validation Accuracy: %.2f%%\n' % (scores[1]*100))

scores = model.evaluate(X_test, y_test)
print('Testing Accuracy: %.2f%%\n' % (scores[1]*100))
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8128 - loss: 0.4520
# Training Accuracy: 80.67%
#
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4797 - loss: 0.8004
# Validation Accuracy: 54.00%
#
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5341 - loss: 0.7255
# Testing Accuracy: 55.00%

# %%
y_test_pred = model.predict(X_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

FPR, TPR, _ = roc_curve(y_test, y_test_pred)
plt.plot(FPR, TPR)
plt.plot([0, 1], [0, 1], '--', color='black')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Out:
# Text(0, 0.5, 'True Positive Rate')
